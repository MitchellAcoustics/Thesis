# %%
import soundscapy as sspy
from soundscapy import isd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sspy.database.simulation(add_paq_coords=True, n=300000)
df.head()
# Out:
#    pleasant  vibrant  eventful  chaotic  annoying  monotonous  uneventful  \
# 0         4        5         3        5         5           2           3
# 1         3        5         4        3         5           2           4
# 2         4        5         1        4         2           5           4
# 3         1        3         3        2         4           4           3
# 4         4        1         3        5         3           5           1
#
#    calm  ISOPleasant  ISOEventful
# 0     3    -0.030330     0.366117
# 1     2    -0.060660     0.292893
# 2     1    -0.012563    -0.090990
# 3     4    -0.237437    -0.219670
# 4     2    -0.409010     0.133883

# %%
sns.histplot(df['ISOPleasant'], bins=101)
# Out:
# <AxesSubplot:xlabel='ISOPleasant', ylabel='Count'>

# %%
sns.histplot(df['ISOPleasant'], bins=45)
# Out:
# <AxesSubplot:xlabel='ISOPleasant', ylabel='Count'>

# %%
df.isd.circumplex_jointplot_density(marginal_kind='kde', xlim=(-.75, .75), ylim=(-.75, .75), title="", incl_scatter=True)

# %%
df.isd.circumplex_jointplot_density(marginal_kind='kde', title="", incl_scatter=True)

# %%
df[['ISOPleasant', 'ISOEventful']].describe()
# Out:
#          ISOPleasant    ISOEventful
# count  300000.000000  300000.000000
# mean        0.000122       0.000441
# std         0.293367       0.292795
# min        -1.000000      -1.000000
# 25%        -0.207107      -0.207107
# 50%         0.000000       0.000000
# 75%         0.207107       0.207107
# max         1.000000       1.000000

# %%
len(df['ISOPleasant'].unique())
# Out:
# 255
